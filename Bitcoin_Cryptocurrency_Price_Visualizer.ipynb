# %% [markdown]
# <a href="https://colab.research.google.com/github/Muskan-Y/Bitcoin-Crptocurrency-Price-Visualizer/blob/main/Bitcoin_Cryptocurrency_Price_Visualizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # DATASET 1: 'BTC-2017min.csv'

# %%
data_dir = 'BTC-2017min.csv'
df=pd.read_csv(data_dir)

# %%
df.head()
# Out:
#          unix                 date   symbol  ...     close  Volume BTC    Volume USD
# 0  1514764740  2017-12-31 23:59:00  BTC/USD  ...  13880.00    0.591748   8213.456549
# 1  1514764680  2017-12-31 23:58:00  BTC/USD  ...  13953.77    1.398784  19518.309658
# 2  1514764620  2017-12-31 23:57:00  BTC/USD  ...  13913.26    0.775012  10782.944294
# 3  1514764560  2017-12-31 23:56:00  BTC/USD  ...  13859.58    0.666459   9236.841134
# 4  1514764500  2017-12-31 23:55:00  BTC/USD  ...  13825.05    0.065501    905.560130
#
# [5 rows x 9 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8586596219987308364 = autoviz.get_df('df_8586596219987308364')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
# ...

# %%
df.tail()
# Out:
#              unix                 date  ... Volume BTC     Volume USD
# 10040  1514162340  2017-12-25 00:39:00  ...  12.883018  183890.138791
# 10041  1514162280  2017-12-25 00:38:00  ...   7.627287  108627.749169
# 10042  1514162220  2017-12-25 00:37:00  ...  14.280368  203168.367657
# 10043  1514162160  2017-12-25 00:36:00  ...  67.812837  965829.750302
# 10044  1514162100  2017-12-25 00:35:00  ...        NaN            NaN
#
# [5 rows x 9 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4249025372186119097 = autoviz.get_df('df_4249025372186119097')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10045 entries, 0 to 10044
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unix        10045 non-null  int64
#  1   date        10045 non-null  object
#  2   symbol      10045 non-null  object
#  3   open        10045 non-null  float64
#  4   high        10045 non-null  float64
#  5   low         10045 non-null  float64
#  6   close       10045 non-null  float64
#  7   Volume BTC  10044 non-null  float64
#  8   Volume USD  10044 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 706.4+ KB

# %%
df.describe()
# Out:
#                unix          open  ...    Volume BTC    Volume USD
# count  1.004500e+04  10045.000000  ...  10044.000000  1.004400e+04
# mean   1.514463e+09  14304.842650  ...     10.476445  1.492382e+05
# std    1.739932e+05    942.614102  ...     16.114426  2.274860e+05
# min    1.514162e+09  12092.270000  ...      0.000000  0.000000e+00
# 25%    1.514313e+09  13737.320000  ...      2.155585  3.084096e+04
# 50%    1.514463e+09  14184.980000  ...      5.402752  7.714098e+04
# 75%    1.514614e+09  14999.380000  ...     12.440160  1.761925e+05
# max    1.514765e+09  16480.480000  ...    340.923053  4.602461e+06
#
# [8 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_60988654540655592 = autoviz.get_df('df_60988654540655592')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date',inplace=True)

# %%
plt.figure(figsize=(15,6))
df[r'open'].plot()
df[r'close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title('Opening & closing Price of Bitcoin')
plt.legend(['Open Price','Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,6))
df[r'high'].plot()
df[r'low'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title('High & Low Price of Bitcoin')
plt.legend(['High Price','Low Price'])
plt.tight_layout()
plt.show()

# %%
n_cols = 1
dataset = df[r'close']
dataset = pd.DataFrame(dataset)
data = dataset.values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(np.array(data))

# %%
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print('Train Size:', train_size, 'Test Size:', test_size)
# Out:
# Train Size: 7533 Test Size: 2512

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (7533, 1)

# %%
x_train = []
y_train = []
time_steps = 60
n_cols = 1

for i in range(time_steps,len(train_data)):
  x_train.append(train_data[i-time_steps:i, :n_cols])
  y_train.append(train_data[i, :n_cols])
  if i <= time_steps:
    print('X_train:', x_train)
    print('y_train:', y_train)
# Out:
# X_train: [array([[0.82732867],
#        [0.83222691],
#        [0.82953709],
#        [0.82597281],
#        [0.82368006],
#        [0.82562089],
#        [0.82760423],
#        [0.8275365 ],
#        [0.82766067],
#        [0.83046801],
#        [0.83047199],
#        [0.83146863],
#        [0.8314195 ],
#        [0.82792692],
#        [0.83064595],
#        [0.82805574],
#        [0.83064861],
#        [0.83263194],
#        [0.83461926],
#        [0.83248188],
#        [0.83247458],
#        [0.83528391],
#        [0.83447849],
#        [0.83289886],
#        [0.83452231],
#        [0.83245399],
#        [0.83244802],
#        [0.83264057],
#        [0.83208216],
#        [0.83064861],
#        [0.83064927],
#        [0.83197659],
#        [0.83064861],
#        [0.83064861],
#        [0.83064861],
#        [0.82785986],
#        [0.82786252],
#        [0.83106559],
#        [0.82639909],
#        [0.82388125],
#        [0.82253866],
#        [0.82355855],
#        [0.82836516],
# ...

# %%
x_train,y_train = np.array(x_train),np.array(y_train)

# %%
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],n_cols))

# %%
x_train.shape,y_train.shape
# Out:
# ((7473, 60, 1), (7473, 1))

# %%
model = Sequential([
    LSTM(50, return_sequences=True,input_shape=(x_train.shape[1],n_cols)),
    LSTM(64, return_sequences=False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model.compile(optimizer = 'adam', loss = 'mse' , metrics = 'mean_absolute_error')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_2 (LSTM)               (None, 60, 50)            10400
#
#  lstm_3 (LSTM)               (None, 64)                29440
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 1)                 17
#
# ...
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **EPOCH TRAINING STARTS**

# %%
history = model.fit(x_train,y_train,epochs = 100,batch_size=32)
# Out:
# Epoch 1/100
# 234/234 [==============================] - 15s 47ms/step - loss: 0.0101 - mean_absolute_error: 0.0394
# Epoch 2/100
# 234/234 [==============================] - 11s 46ms/step - loss: 1.1474e-04 - mean_absolute_error: 0.0085
# Epoch 3/100
# 234/234 [==============================] - 11s 47ms/step - loss: 3.1446e-05 - mean_absolute_error: 0.0043
# Epoch 4/100
# 234/234 [==============================] - 11s 46ms/step - loss: 2.6572e-05 - mean_absolute_error: 0.0039
# Epoch 5/100
# 234/234 [==============================] - 11s 47ms/step - loss: 2.8408e-05 - mean_absolute_error: 0.0041
# Epoch 6/100
# 234/234 [==============================] - 11s 46ms/step - loss: 2.6952e-05 - mean_absolute_error: 0.0040
# Epoch 7/100
# 234/234 [==============================] - 11s 46ms/step - loss: 2.8046e-05 - mean_absolute_error: 0.0041
# Epoch 8/100
# 234/234 [==============================] - 11s 45ms/step - loss: 3.0682e-05 - mean_absolute_error: 0.0043
# Epoch 9/100
# ...

# %%
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 1

for i in range(time_steps,len(test_data)):
  x_test.append(test_data[i-time_steps:i, 0:n_cols])
  y_test.append(test_data[i, 0:n_cols])

x_test,y_test = np.array(x_test),np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],n_cols))

# %%
x_test.shape,y_test.shape
# Out:
# ((2512, 60, 1), (2512, 1))

# %%
predictions = model.predict(x_test)
# Out:
# 79/79 [==============================] - 2s 13ms/step

# %%
predictions = scaler.inverse_transform(y_test)

rmse = np.sqrt(np.mean(y_test - predictions)**2).round(2)
rmse
# Out:
# 14445.94

# %%
preds_acts = pd.DataFrame(data={'Predictions': predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#       Predictions   Actuals
# 0        15700.00  0.948174
# 1        15735.03  0.950500
# 2        15736.72  0.950613
# 3        15799.45  0.954778
# 4        15800.00  0.954814
# ...           ...       ...
# 2507     14273.84  0.853479
# 2508     14241.99  0.851364
# 2509     14227.11  0.850376
# 2510     14242.58  0.851404
# 2511      1420.00  0.000000
#
# [2512 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5289935503011274729 = autoviz.get_df('df_5289935503011274729')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
# ...

# %%
plt.figure(figsize = (16,6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions', 'Actuals'])
plt.show()

# %% [markdown]
# # DATASET 2: 'BTC-USD'

# %%
import yfinance as yf
import os
import pandas as pd

# %%
btc_ticker = yf.Ticker("BTC-USD")

# %%
if os.path.exists("btc.csv"):
    btc = pd.read_csv("btc.csv", index_col=0)
else:
    btc = btc_ticker.history(period="max")
    btc.to_csv("btc.csv")

# %%
btc
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2023-07-05 00:00:00+00:00  30778.724609  30877.330078  30225.613281
# 2023-07-06 00:00:00+00:00  30507.150391  31460.052734  29892.226562
# 2023-07-07 00:00:00+00:00  29907.998047  30434.644531  29777.285156
# 2023-07-08 00:00:00+00:00  30346.921875  30374.437500  30080.160156
# 2023-07-09 00:00:00+00:00  30304.685547  30398.357422  30250.904297
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# ...

# %%
btc.index = pd.to_datetime(btc.index)

# %%
del btc["Dividends"]
del btc["Stock Splits"]

# %%
btc.columns = [c.lower() for c in btc.columns]

# %%
btc.plot.line(y="close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
wiki = pd.read_csv("wikipedia_edits.csv", index_col=0,parse_dates=True)

# %%
wiki
# Out:
#             edit_count  editor_count     ratio  difference  sentiment  \
# 2009-04-06    0.133333      0.066667  4.408755    4.633333  -0.032780
# 2009-04-07    0.000000      0.000000  0.000000    0.000000   0.000000
# 2009-04-08    0.000000      0.000000  0.000000    0.000000   0.000000
# 2009-04-09    0.000000      0.000000  0.000000    0.000000   0.000000
# 2009-04-10    0.000000      0.000000  0.000000    0.000000   0.000000
# ...                ...           ...       ...         ...        ...
# 2022-09-03    0.266667      0.200000  0.000092   20.588889  -0.092629
# 2022-09-04    0.266667      0.200000  0.000092   20.588889  -0.092629
# 2022-09-05    0.266667      0.200000  0.000092   20.588889  -0.092629
# 2022-09-06    0.266667      0.200000  0.000092   20.588889  -0.092629
# 2022-09-07    0.266667      0.200000  0.000092   20.588889  -0.092629
#
#             neg_sentiment  total_difference
# 2009-04-06       0.033333         18.533333
# ...

# %%
btc["tomorrow"] = btc["close"].shift(-1)

# %%
btc["target"] = (btc["tomorrow"] > btc["close"]).astype(int)

# %%
btc["target"].value_counts()
# Out:
# 1    1709
# 0    1509
# Name: target, dtype: int64

# %%
btc
# Out:
#                                    open          high           low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2023-07-05 00:00:00+00:00  30778.724609  30877.330078  30225.613281
# 2023-07-06 00:00:00+00:00  30507.150391  31460.052734  29892.226562
# 2023-07-07 00:00:00+00:00  29907.998047  30434.644531  29777.285156
# 2023-07-08 00:00:00+00:00  30346.921875  30374.437500  30080.160156
# 2023-07-09 00:00:00+00:00  30304.685547  30398.357422  30250.904297
#
#                                   close       volume      tomorrow  target
# Date
# ...

# %% [markdown]
# You can also use some MORE parameters and functions to analyze the performance for Bitcoin price evaluation
